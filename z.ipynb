# %% [markdown]
# ### **ML Lifecycle**
#
# > Planning Phase (Problem Framing & Business Goal) > Data Collection > Data Profiling > Data Pre-processing > Data Validation > Prototyping > Feature Engineering > Model Engineering > Model Validation > Mode Training > Model Evaluation > Hyperparameter Tuning > Model Deployment & Inference > Model Monitoring & Maintenance > Feedback Loops
#
# ##### **Project Introduction**
#
# 1. Objective
# 1. Understand the Problem
# 1. Framing an ML Problem
# 1. Table of Contents
#
# ##### **Data Preparation**
#
# 1. Data Collection
# 1. Data Profiling
# 1. Data Pre-processing
# 1. Data Validation
#
# ##### **Feature Engineering and Selection**
#
# 1. Feature Engineering /Selection
#
# ##### **AutoML**
#
# 1. Prototyping
# 1. Model Validation
# 1. Mode Training
# 1. Model Evaluation
#
# ##### **Custom Training**
#
# 1. Model Engineering
# 1. Model Validation
# 1. Mode Training
# 1. Model Evaluation
# 1. Hyperparameter Tuning
#
# ##### **MLOPs**
#
# 1. Model Deployment & Inference
# 1. Model Monitoring & Maintenance
# 1. Feedback Loops
#
# ***
# ***

# %% [markdown]
# ### **Vertex Ai [AutoML + Custom Training]**
#
# ##### **Practice Projects**
#
# 1. Titanic - Machine Learning from Disaster
# 1. Spaceship Titanic
# 1. Digit Recognizer
# 1. Facial Keypoints Detection
# 1. Natural Language Processing with Disaster Tweets
# 1. Bag of Words Meets Bags of Popcorn
#
# ##### **Portfolio Projects**
#
# 1. I’m Something of a Painter Myself
# 1. Petals to the Metal - Flower Classification on TPU
# 1. Contradictory, My Dear Watson
#
# '''
#
# ### **BigQueryML**
#
# ##### **Practice Projects**
#
# 1. House Prices - Advanced Regression Techniques
#
# ##### **Portfolio Projects**
#
# 1. Store Sales - Time Series Forecasting
#
# '''
#
# ### **Misc**
#
# 1. Just the Basics - Strata 2013
# 1. Just the Basics - Strata 2013 After-party
# 1. Connect X
# 1. Data Science London + Scikit-learn
# 1. First Steps With Julia
#
# ***
# ***
